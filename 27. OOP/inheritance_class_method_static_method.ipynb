# %%
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        pass #initially skipping the cls method


emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)

# %%
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        pass #initially skipping the cls method
        cls.raise_amount = amount

emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)
#initial raise amount
print(employee.raise_amount)
print(emp5.raise_amount)
print(emp6.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        # pass #initially skipping the cls method
        cls.raise_amount = amount
employee.set_raise_amount(1.09)

emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)

#now we have chnage the raise amount lets check how the raise amount is doing
print(employee.raise_amount)
print(emp5.raise_amount)
print(emp6.raise_amount)
#now we can see every one of the instance raise amount has changed
#we can also run that class method with the instance too
# Out:
# 1.09
# 1.09
# 1.09

# %%
#running class method with the instance
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        # pass #initially skipping the cls method
        cls.raise_amount = amount


emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)
emp5.set_raise_amount(1.09)

#now we have chnage the raise amount lets check how the raise amount is doing
print(employee.raise_amount)
print(emp5.raise_amount)
print(emp6.raise_amount)
#now we can see every one of the instance raise amount has changed
#we can also run that class method with the instance too
# Out:
# 1.09
# 1.09
# 1.09

# %%
#pass a string and create a employee from that
#running class method with the instance
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        # pass #initially skipping the cls method
        cls.raise_amount = amount


emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)
emp5.set_raise_amount(1.09)

emp_str_1= 'John-Doe-70000'
emp_str_2= 'Steve-Smith-80000'
emp_str_3 = 'Jane-Doe-90000'
first, last, pay = emp_str_1.split('-')
#the work is doing here is really time consuimg and we can make lots of mistake
emp7= employee(first,last,pay)
print(emp7.email)
emp7.full_name()
print(emp7.pay)
# #now we have chnage the raise amount lets check how the raise amount is doing
# print(employee.raise_amount)
# print(emp5.raise_amount)
# print(emp6.raise_amount)
# #now we can see every one of the instance raise amount has changed
# #we can also run that class method with the instance too
# Out:
# John.Doe@yahoo.com
# John Doe
# 70000

# %%
#pass a string and create a employee from that
#running class method with the instance
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        # pass #initially skipping the cls method
        cls.raise_amount = amount
    #lets use class method to create the emp from that class

    @classmethod
    def from_string(cls, emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first,last,pay)

emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)
emp5.set_raise_amount(1.09)

emp_str_1= 'John-Doe-70000'
emp_str_2= 'Steve-Smith-80000'
emp_str_3 = 'Jane-Doe-90000'
emp8= employee.from_string(emp_str_1)
emp9= employee.from_string(emp_str_2)
print(emp9.email)
emp9.full_name()
print(emp8.pay)
# Out:
# Steve.Smith@yahoo.com
# Steve Smith
# 70000

# %%
#creating a static method if a day is week day or not from the employee class we have used so far
#pass a string and create a employee from that
#running class method with the instance
import datetime
class employee():
    num_of_emps =0
    raise_amount = 1.04
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + "@yahoo.com" 
        employee.num_of_emps +=1
    def display(self):
        print(f'Name: {self.first} {self.last}, Email: {self.email}, Pay: {self.pay}')
    def full_name(self):
        print(f"{self.first} {self.last}")
    def apply_raise(self):
        raise_pay = self.pay * self.raise_amount
        return raise_pay
    @classmethod
    def set_raise_amount(cls, amount): #in class method cls is the auto taking class variable
        # pass #initially skipping the cls method
        cls.raise_amount = amount
    #lets use class method to create the emp from that class

    @classmethod
    def from_string(cls, emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first,last,pay)
    @staticmethod
    #static method does not take any parameter it is independent as hell
    #we can access static method from the class
    #if we do not use any method from the function or instance then we use the method as static
    def is_workday(day):
        if day.weekday() == 5 or day.weekday() ==6:
            #5 is saturday and 6 is sunday
            return False
        return True

emp5 = employee('rhs', '2', 80000)
emp6 = employee('sio', '4', 50000)
emp5.set_raise_amount(1.09)

emp_str_1= 'John-Doe-70000'
emp_str_2= 'Steve-Smith-80000'
emp_str_3 = 'Jane-Doe-90000'
emp8= employee.from_string(emp_str_1)
emp9= employee.from_string(emp_str_2)
my_date = datetime.date(2016,7,16)
employee.is_workday(my_date)
print(emp7.__dict__)
print(employee.__dict__)
# Out:
# {'first': 'John', 'last': 'Doe', 'pay': '70000', 'email': 'John.Doe@yahoo.com'}
# {'__module__': '__main__', 'num_of_emps': 4, 'raise_amount': 1.09, '__init__': <function employee.__init__ at 0x10d285c60>, 'display': <function employee.display at 0x10d285d00>, 'full_name': <function employee.full_name at 0x10d286340>, 'apply_raise': <function employee.apply_raise at 0x10d286480>, 'set_raise_amount': <classmethod(<function employee.set_raise_amount at 0x10d286520>)>, 'from_string': <classmethod(<function employee.from_string at 0x10d2863e0>)>, 'is_workday': <staticmethod(<function employee.is_workday at 0x10d2865c0>)>, '__dict__': <attribute '__dict__' of 'employee' objects>, '__weakref__': <attribute '__weakref__' of 'employee' objects>, '__doc__': None}
